# %% [markdown]
# <a href="https://colab.research.google.com/github/paragrafff22/SkyTasks/blob/SkyTests/XOR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from keras.models import Sequential
from keras.layers.core import Activation, Dense
# Out:
# Using TensorFlow backend.

# %%
#data
x = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([[0],[1],[1],[0]])

# %%
#model
model = Sequential()

model.add(Dense(16, activation="relu", input_shape=(2,)))
model.add(Dense(1, activation="sigmoid"))

model.compile(optimizer='adam', loss="mean_squared_error", metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_8 (Dense)              (None, 16)                48
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 17
# ...
# Total params: 65
# Trainable params: 65
# Non-trainable params: 0
# _________________________________________________________________

# %%
#training model
model.fit(x, y, batch_size=4, epochs=1000)
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2557 - accuracy: 0.7500
# Epoch 2/1000
# 4/4 [==============================] - 0s 616us/step - loss: 0.2553 - accuracy: 0.5000
# Epoch 3/1000
# 4/4 [==============================] - 0s 350us/step - loss: 0.2550 - accuracy: 0.5000
# Epoch 4/1000
# 4/4 [==============================] - 0s 326us/step - loss: 0.2546 - accuracy: 0.5000
# Epoch 5/1000
# 4/4 [==============================] - 0s 450us/step - loss: 0.2543 - accuracy: 0.5000
# Epoch 6/1000
# 4/4 [==============================] - 0s 441us/step - loss: 0.2539 - accuracy: 0.5000
# Epoch 7/1000
# 4/4 [==============================] - 0s 348us/step - loss: 0.2536 - accuracy: 0.5000
# Epoch 8/1000
# 4/4 [==============================] - 0s 414us/step - loss: 0.2532 - accuracy: 0.5000
# Epoch 9/1000
# 4/4 [==============================] - 0s 444us/step - loss: 0.2529 - accuracy: 0.5000
# Epoch 10/1000
# ...

# %%
predtiction = model.predict(x)
print(predtiction)
# Out:
# [[0.13910191]
#  [0.8976166 ]
#  [0.89791226]
#  [0.10173075]]

# %%
print(np.round(predtiction))
# Out:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
